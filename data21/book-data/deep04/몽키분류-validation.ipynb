# %%
# numpy를 가져오는 것은 기본이다.
import numpy as np  

# os  모듈을 로딩 하고 디렉토리 확인 
import os
print(os.getcwd())
# Out:
# /Users/administrator/AI-python_workspace/book-data/06.딥러닝

# %%
import glob  # 
from glob import glob

# %%
# 디렉토리 위치 바꾸기
data_list = []
for x in range(10):
    data_dir = os.chdir("/Users/administrator/AI-python_workspace/book-data/06.딥러닝/img-monky/validation/validation/n" + str(x))
    one_list = glob('*.jpg')
    data_list = data_list + one_list
    print('-----' , data_list[1:5], '-----len---> ', len(one_list))
# Out:
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  26
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  28
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  27
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  30
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  26
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  28
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  26
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  28
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  27
# ----- ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg'] -----len--->  26

# %%
len(data_list)
# Out:
# 272

# %%
del data_list[:]

# %%
# 파일이름을 리스트 형태로 변환 하는데 사용
# data_list = glob('*.jpg')
# data_list[1:5]
# Out:
# ['n0011.jpg', 'n0013.jpg', 'n0012.jpg', 'n0016.jpg']

# %%
# len(data_list)
# Out:
# 26

# %%
label = []

# %%
for i, x in enumerate(['n0','n1','n2','n3','n4','n5','n6','n7', 'n8', 'n9' ]):
    if (i in [0, 4, 6, 9]) : 
        n = 26
    elif (i in [1, 5, 7]) :
        n = 28
    elif (i in [2, 8]):
        n = 27
    else:
        n = 30
    label = label + ([x] * n)
    print(label)
    print('------', len(label))
# Out:
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0']
# ------ 26
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1']
# ------ 54
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2']
# ------ 81
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3']
# ------ 111
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4']
# ------ 137
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5']
# ------ 165
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6']
# ------ 191
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7']
# ------ 219
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8']
# ------ 246
# ['n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n0', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n1', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n2', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n3', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n4', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n5', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n6', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n7', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n8', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9', 'n9']
# ------ 272

# %%
# del label[:] #리스트 전체 삭제

# %%
len(label)
# Out:
# 272

# %%
# label = ['a'] * 26

# %%
# label[:3]
# Out:
# ['a', 'a', 'a']

# %%
# ['b'] * 26

# %%
# !pip install cv2
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-macosx_10_15_x86_64.whl (46.0 MB)
#      |████████████████████████████████| 46.0 MB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /Users/administrator/opt/anaconda3/lib/python3.7/site-packages (from opencv-python) (1.19.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.62

# %%
data_list[0]
# Out:
# 'n0010.jpg'

# %%
data_dir = os.chdir("/Users/administrator/AI-python_workspace/book-data/06.딥러닝/img-monky/validation/total" )

# %%
import cv2
from matplotlib import pyplot as plt

# 20번째 있는 사진의 샘플을 본다. 
img = cv2.imread(data_list[0])
plt.imshow(img)
plt.show()

# %%
# 이미지를 데이터 셋으로 변환 하고,  이것을 255로 나누어 0 ~ 1로 스케일 한다.
image = cv2.imread(data_list[0])/255
image.shape
# Out:
# (816, 1024, 3)

# %%
data_height = 28
data_width = 28
channel_n = 3

# %%
images = np.zeros((100, data_height, data_width, channel_n)) 
for n, path in enumerate(data_list[:100]):
    image = cv2.imread(data_list[n])
    image = cv2.resize(image, (data_height, data_width))
    images[n, :, :, :] =image

# %%
image.shape
# Out:
# (28, 28, 3)

# %%
image[0]
# Out:
# array([[179, 173, 175],
#        [184, 179, 180],
#        [180, 175, 176],
#        [184, 179, 180],
#        [187, 182, 183],
#        [201, 198, 197],
#        [218, 213, 212],
#        [231, 226, 225],
#        [241, 236, 235],
#        [247, 242, 239],
#        [249, 244, 243],
#        [249, 243, 240],
#        [244, 239, 236],
#        [241, 236, 235],
#        [236, 231, 230],
#        [230, 225, 225],
#        [226, 221, 220],
#        [223, 218, 217],
#        [215, 211, 207],
#        [208, 204, 201],
#        [209, 203, 204],
#        [209, 204, 203],
#        [214, 209, 207],
#        [219, 214, 211],
#        [222, 217, 214],
#        [223, 218, 215],
#        [229, 222, 219],
#        [231, 224, 221]], dtype=uint8)

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import cv2

# %%
image[0][0][0]
# Out:
# 179

# %%
len(image[0])
# Out:
# 28

# %%
#########

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import cv2

# %%
# image initialization
data_height = 28
data_width = 28
channel_n = 3
batch_size = len(data_list)

# %%
# data processing 함수 
from tensorflow.keras.preprocessing.text import text_to_word_sequence

def make_file(data_height, data_width, channel_n, batch_size):
    label = []
    images = np.zeros((batch_size, data_height, data_width, channel_n))
    for n, path in enumerate(data_list[:batch_size]):

    # lable 
        token = text_to_word_sequence(data_list[n])
        label.append(token[0])
        
    # image transform
        image = cv2.imread(data_list[n])
        image = cv2.resize(image, (data_height, data_width))/255
        images[n, :, :, :] =image
    
    label = np.array(label)
        
    return (label, images)

# %%
# 함수를 이용하여 라벨과 이미지 데이터셋을 가져오기 
(label, images) = make_file(data_height, data_width, channel_n, batch_size)

# 이미지 데이터 구조와 라벨 구조를 보기
print(images.shape, label.shape)
# Out:
# (272, 28, 28, 3) (272,)

# %%
images[0][0]
# Out:
# array([[0.43137255, 0.65098039, 0.67843137],
#        [0.96078431, 0.95686275, 0.56078431],
#        [0.30588235, 0.50196078, 0.34117647],
#        [0.1372549 , 0.4       , 0.30196078],
#        [0.3372549 , 0.51764706, 0.34901961],
#        [0.44313725, 0.63529412, 0.46666667],
#        [0.43529412, 0.47058824, 0.4627451 ],
#        [0.94901961, 1.        , 0.71372549],
#        [0.23921569, 0.53333333, 0.32941176],
#        [0.29803922, 0.47843137, 0.30196078],
#        [0.14901961, 0.42745098, 0.23529412],
#        [0.39215686, 0.56862745, 0.48627451],
#        [0.27843137, 0.51764706, 0.38431373],
#        [0.14117647, 0.27058824, 0.32941176],
#        [0.41176471, 0.49019608, 0.54117647],
#        [0.03921569, 0.47843137, 0.22352941],
#        [0.8745098 , 0.98823529, 0.95294118],
#        [0.18039216, 0.5372549 , 0.3372549 ],
#        [0.40392157, 0.68235294, 0.59215686],
#        [0.32941176, 0.62352941, 0.43529412],
#        [0.50980392, 0.66666667, 0.51372549],
#        [0.06666667, 0.48235294, 0.21960784],
#        [0.1372549 , 0.58431373, 0.32156863],
#        [0.10588235, 0.58823529, 0.40784314],
#        [0.07843137, 0.41960784, 0.22352941],
#        [0.36862745, 0.56862745, 0.4627451 ],
#        [0.25882353, 0.43137255, 0.37254902],
#        [0.43921569, 0.60392157, 0.53333333]])

# %%
len(images[0][0])
# Out:
# 28

# %%
# data label encoder
from sklearn.preprocessing import LabelEncoder
items = label
encoder = LabelEncoder()
encoder.fit(items)
label = encoder.transform(items)

# %%
# data split train set, test set
from sklearn.model_selection import train_test_split
x = images 
y = label

# %%
X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=1004)

# 데이터 셋이  나누어진 것에 대한 구조보기
print(X_train.shape, X_test.shape)
# Out:
# (190, 28, 28, 3) (82, 28, 28, 3)

# %%
# CNN model network
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(data_height, data_width, channel_n)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 64)                73792
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 167,105
# Trainable params: 167,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=(X_test,y_test),
                                                       batch_size=20,
                                                       epochs=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 1s 21ms/step - loss: -866.2322 - accuracy: 0.0000e+00 - val_loss: -4871.0947 - val_accuracy: 0.0122
# Epoch 2/5
# 10/10 [==============================] - 0s 10ms/step - loss: -21566.7930 - accuracy: 0.0000e+00 - val_loss: -74057.7734 - val_accuracy: 0.0122
# Epoch 3/5
# 10/10 [==============================] - 0s 10ms/step - loss: -208283.4062 - accuracy: 0.0000e+00 - val_loss: -529394.3125 - val_accuracy: 0.0122
# Epoch 4/5
# 10/10 [==============================] - 0s 10ms/step - loss: -1131767.0000 - accuracy: 0.0000e+00 - val_loss: -2527270.5000 - val_accuracy: 0.0122
# Epoch 5/5
# 10/10 [==============================] - 0s 10ms/step - loss: -4634189.5000 - accuracy: 0.0000e+00 - val_loss: -9273947.0000 - val_accuracy: 0.0122

# %%
# model chart
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'validation'])

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'validation'])

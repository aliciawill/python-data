# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json

client_id = 'hfhBxkqxdEy5alw1C5Rs'
client_secret = 'rHJC0Vf0W5'

encText = urllib.parse.quote("코로나")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +'&start=1&display=100'
# json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read().decode('utf-8')
#     res_json = response_body.json()
#     print(response_body.decode('utf-8'))
    json_data = json.loads(response_body)
    print(json_data)
else:
    print("Error Code:" + rescode)
# Out:
# {'lastBuildDate': 'Mon, 21 Mar 2022 18:00:42 +0900', 'total': 19896111, 'start': 1, 'display': 100, 'items': [{'title': '<b>코로나</b> 자가진단 키트 자가검사 후기 결과는? (사용법, 정확도)', 'link': 'https://blog.naver.com/green557?Redirect=Log&logNo=222662770170', 'description': '<b>코로나</b> 자가진단 키트 자가검사 후기 결과는? (사용법, 정확도) 확진자 만명대는 외국에서나 있는... 실제로 제 주변에서도 많이 걸리는 만큼 요즘은 누구나 필수로 #<b>코로나</b>자가검사키트 라는 것을 구비해... ', 'bloggername': '살아있는인형가게 ``°³о♡', 'bloggerlink': 'https://blog.naver.com/green557', 'postdate': '20220303'}, {'title': '&lt;<b>코로나</b>19확진 3월&gt; 자가격리 기록 1일차', 'link': 'https://blog.naver.com/fksl0902?Redirect=Log&logNo=222676204454', 'description': '2020년 2월 발생한 <b>코로나</b>19_ 그 이후로 1년은 남편과 동거동락하며 주변 사람들과의 접촉, 나아가 가족들과의 대면 식사도 미루어 하지 않았었다. 심각성을 받아들이고 조심했던 지난 2020-2021년 2년!!! <b>코로나</b>가... ', 'bloggername': '분주한 일상에 소소한 기쁨', 'bloggerlink': 'https://blog.naver.com/fksl0902', 'postdate': '20220320'}, {'title': '오미크론 증상 발현후 <b>코로나</b> 치료제 팍스로비드 복용 내 몸이... ', 'link': 'https://blog.naver.com/ds4cdl?Redirect=Log&logNo=222654646435', 'description': '확진후 <b>코로나</b>치료제를 복용했다 지금은 하루 확진자 60만 시대 ㅜㅜ 정부는 긴급히 먹는치료제 머크... 증상을 이야기 했더니 혹시모를 악화에 대비해 <b>코로나</b> 먹는치료제를 처방해준다. TV에서만 듣던... ', 'bloggername': '김인곤 공식블로그', 'bloggerlink': 'https://blog.naver.com/ds4cdl', 'postdate': '20220222'}, {'title': '<b>코로나</b> 자가격리 지원금, 생활지원금 신청 방법 (ft. 구호물품... ', 'link': 'https://blog.naver.com/nara212?Redirect=Log&logNo=222657110827', 'description': '<b>코로나</b> 자가격리 지원금 생활지원금 신청 방법 <b>코로나</b>와 관련된 검색으로 이 블로그에 들어오신 분들은 이전의 확진 스토리를 보셨을텐데 못보신 분들은 글 하단에 관련된 글들을 남겨놓았으니 참고하시길... ', 'bloggername': '콕콕스런생활', 'bloggerlink': 'https://blog.naver.com/nara212', 'postdate': '20220224'}, {'title': '아기 <b>코로나</b> 열내리는법/열내림 증상', 'link': 'https://blog.naver.com/betty6649?Redirect=Log&logNo=222676059139', 'description': '나거나 <b>코로나</b> 증상은 보이지 않아서 한시름 놨었거든요 그때 못난 애미는 정말 아무것도 모른 채 아기 <b>코로나</b> 증상이나 아기 열내리는 법 등을 부랴부랴 알아보며 진작 좀 알아둘걸 싶었다는...ㅠㅠ 이제는... ', 'bloggername': '유치원선생님 복떵이맘의 엄마 적응기 :-)', 'bloggerlink': 'https://blog.naver.com/betty6649', 'postdate': '20220318'}, {'title': '<b>코로나</b> 확진자 재택치료 기간 1-5일차 일기', 'link': 'https://blog.naver.com/daheeprint?Redirect=Log&logNo=222637784239', 'description': '집앞 근처 중랑구청에서 pcr 검사를 처음해보았다 혹시 설마했는데....<b>코로나</b> 양성이라고 다음날 아침... <b>코로나</b> 확진자라니 재택치료를 들어갔다 얼마전에 법이 바뀌었다며 한숨을 쉬며 전화하시는 여자분... ', 'bloggername': '고디공간만의 트랜디함을 담아, 고디자인스튜디오', 'bloggerlink': 'https://blog.naver.com/daheeprint', 'postdate': '20220203'}, {'title': '<b>코로나</b> 자가진단키트 사용법 (ft. 가격, 정확도)', 'link': 'https://blog.naver.com/dltptkddlek?Redirect=Log&logNo=222676490406', 'description': '<b>코로나</b> 자가진단키트 사용법 (ft. 가격, 정확도) 안녕하세요 플렉스햄찌입니다. 다들 잘지내고계신가요?... 회사에서 이전에 단체로 나눠줬던 <b>코로나</b> 자가진단키트는 휴마시스꺼였는데, 이번에 약국에서 사온건... ', 'bloggername': '내 인생의 재무제표', 'bloggerlink': 'https://blog.naver.com/dltptkddlek', 'postdate': '20220318'}, {'title': '<b>코로나</b> 확진자 생활지원금 신청 신청서 자가격리', 'link': 'https://blog.naver.com/dongi0508?Redirect=Log&logNo=222673843823', 'description': '<b>코로나</b> 확진자 생활지원금 신청 신청서 자가격리 드디어! 우리 가정에도 확진자가 한 명 발생했다!... 그러는 와중에 <b>코로나</b> 생활지원금 이거 예산이 부족한가부다... 금액이 훨씬 더 줄어들었다는. 아무래도... ', 'bloggername': 'Der Sinn des Lebens', 'bloggerlink': 'https://blog.naver.com/dongi0508', 'postdate': '20220316'}, {'title': '<b>코로나</b> 자가키트 사용법 - 휴마시스 코비드-19 홈 테스트', 'link': 'https://blog.naver.com/tellin9vi?Redirect=Log&logNo=222660073834', 'description': '이제 필수품이 된 자가키트 증상이 있거나 동선이 겹치거나 한 건 아니지만 학원에서 요구가 있어서 <b>코로나</b> 자가키트를 직접 사용해봤다. 휴마시스 코비드 -19 홈 테스트 <b>코로나</b> 자가키트 원래 두 개가... ', 'bloggername': 'Wednesday Story', 'bloggerlink': 'https://blog.naver.com/tellin9vi', 'postdate': '20220228'}, {'title': '<b>코로나</b> 증상 및 확진자가족 격리기간', 'link': 'https://blog.naver.com/darki113?Redirect=Log&logNo=222677529466', 'description': '<b>코로나</b> 증상 및 확진자가족 격리기간 by. 헬로랑이 우리집에도 <b>코로나</b>가 찾아왔다.. 주말 아침부터 캠핑놀이한다고 형아랑 신나게 노는 막내 이불로 텐트도 만들고 캠핑의자에 앉아서 간식도 먹고 평소와 같은... ', 'bloggername': '헬로랑이 Storyhouse', 'bloggerlink': 'https://blog.naver.com/darki113', 'postdate': '20220320'}, {'title': '<b>코로나</b> 확진 격리 해제 후 소독방법, <b>코로나</b> 생 ...

# %%
type(json_data)
# Out:
# dict

# %%
json_data['items'][0]['title']
# Out:
# '<b>코로나</b> 자가진단 키트 자가검사 후기 결과는? (사용법, 정확도)'

# %%
#################### naver API connection test ####################

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = 'hfhBxkqxdEy5alw1C5Rs'
client_secret = 'rHJC0Vf0W5'
encText = urllib.parse.quote("자동차")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    res_data = response_body.decode('utf-8')
    print(type(res_data))
    json_data = json.loads(res_data)
    print(type(json_data)) ##dict이여야 key로 추출 가능함.
    #print(res_data)
else:
    print("Error Code:" + rescode)
# Out:
# <class 'str'>
# <class 'dict'>
